# %%
import pandas as pd
import os
from IPython.display import display, Image

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# 'E:\\GitHub\\IA\\ia_dump\\EN\\FILES'

# %%
img_ware_path = 'E:\\GitHub\\IA\\ia_dump\\EN\\ASSETS\\icon\\ware\\'
img_bless_path = 'E:\\GitHub\\IA\\ia_dump\\EN\\ASSETS\\icon\\warebless\\'

# %%
ware_path = cwd + '\\ware\\'

# %%
ware = pd.read_csv(ware_path+'cfg_ware.csv')
ware_additional_column = pd.read_csv(ware_path+'cfg_ware_additional_column.csv')
ware_bless = pd.read_csv(ware_path+'cfg_ware_bless.csv')
ware_bless_gift = pd.read_csv(ware_path+'cfg_ware_bless_gift.csv')
ware_bless_pool = pd.read_csv(ware_path+'cfg_ware_bless_pool.csv')
ware_common = pd.read_csv(ware_path+'cfg_ware_common.csv')
ware_game_achievement = pd.read_csv(ware_path+'cfg_ware_game_achievement.csv')
ware_game_dungeon = pd.read_csv(ware_path+'cfg_ware_game_dungeon.csv')
ware_game_event = pd.read_csv(ware_path+'cfg_ware_game_event.csv')
ware_game_hero = pd.read_csv(ware_path+'cfg_ware_game_hero.csv')
ware_game_npc = pd.read_csv(ware_path+'cfg_ware_game_npc.csv')
ware_game_npc_team = pd.read_csv(ware_path+'cfg_ware_game_npc_team.csv')
ware_game_pass = pd.read_csv(ware_path+'cfg_ware_game_pass.csv')
ware_upgrade = pd.read_csv(ware_path+'cfg_ware_upgrade.csv')

# %%
angels = pd.read_csv('E:\\GitHub\\IA\\ia_dump\\EN\\FILES\\hero\\cfg_hero.csv')

# %%
ware
# Out:
#    cfg_id                name  quality_level  attribute_label  basic_skill_id  \
# 0       1     Infernal Spirit              5                1        77771101
# 1       2        Blazing Soul              5                1        77772101
# 2       3    Fearless Warrior              5                1        77773101
# 3       4  Invisible Guardian              5                2        77774101
# 4       5    Sanctuary Maiden              5                2        77775101
# 5       6   Nature's Guardian              5                2        77776101
# 6       7      Immortal Bones              5                3        77777101
# 7       8         Void Shadow              5                3        77778101
# 8       9     Otherworld Sage              5                3        77779101
#
#    upgrade_skill_id  basic_slot      icon
# 0          77771201           7  1001.png
# 1          77772201           7  1002.png
# 2          77773201           7  1003.png
# ...

# %%
ware_additional_column
# Out:
#      id  cfg_id                     name  type  quality_level  \
# 0     1       1                  ATK +1%     1              1
# 1     2       1                  ATK +3%     1              2
# 2     3       1                  ATK +5%     1              3
# 3     4       1                 ATK +10%     1              4
# 4     5       2                 CRIT +3%     1              1
# ..  ...     ...                      ...   ...            ...
# 84   85      22                   SPD +3     1              1
# 85   86      22                   SPD +5     1              2
# 86   87      22                  SPD +10     1              3
# 87   88      22                  SPD +20     1              4
# 88  999     999  Level up Essence Skills     2              4
#
#     attribute_label  attr_is_ratio fight_attribute  weight       icon
# 0                 1              0          3:1:10     120   1001.png
# 1                 1              0          3:1:30      50   1002.png
# ...

# %%
ware_additional_column.nunique()
# Out:
# id                 89
# cfg_id             23
# name               89
# type                2
# quality_level       4
# attribute_label     4
# attr_is_ratio       2
# fight_attribute    89
# weight             10
# icon               89
# dtype: int64

# %%
attr_0 = ware_additional_column[ware_additional_column.attribute_label == 0]
attr_1 = ware_additional_column[ware_additional_column.attribute_label == 1]
attr_2 = ware_additional_column[ware_additional_column.attribute_label == 2]
attr_3 = ware_additional_column[ware_additional_column.attribute_label == 3]

# %%
attr_0
# Out:
#      id  cfg_id                     name  type  quality_level  \
# 88  999     999  Level up Essence Skills     2              4
#
#     attribute_label  attr_is_ratio fight_attribute  weight     icon
# 88                0              0               0       3  999.png

# %%
attr_1
# Out:
#     id  cfg_id                 name  type  quality_level  attribute_label  \
# 0    1       1              ATK +1%     1              1                1
# 1    2       1              ATK +3%     1              2                1
# 2    3       1              ATK +5%     1              3                1
# 3    4       1             ATK +10%     1              4                1
# 4    5       2             CRIT +3%     1              1                1
# 5    6       2             CRIT +5%     1              2                1
# 6    7       2             CRIT +7%     1              3                1
# 7    8       2            CRIT +15%     1              4                1
# 8    9       3         CRIT DMG +3%     1              1                1
# 9   10       3         CRIT DMG +5%     1              2                1
# 10  11       3         CRIT DMG +7%     1              3                1
# 11  12       3        CRIT DMG +15%     1              4                1
# ...

# %%
attr_2
# Out:
#     id  cfg_id                 name  type  quality_level  attribute_label  \
# 24  25       7               HP +3%     1              1                2
# 25  26       7               HP +5%     1              2                2
# 26  27       7              HP +10%     1              3                2
# 27  28       7              HP +20%     1              4                2
# 28  29       8              DEF +1%     1              1                2
# 29  30       8              DEF +3%     1              2                2
# 30  31       8              DEF +5%     1              3                2
# 31  32       8             DEF +10%     1              4                2
# 32  33       9        RES Boost +1%     1              1                2
# 33  34       9        RES Boost +2%     1              2                2
# 34  35       9        RES Boost +3%     1              3                2
# 35  36       9        RES Boost +5%     1              4                2
# ...

# %%
attr_3
# Out:
#     id  cfg_id                  name  type  quality_level  attribute_label  \
# 48  49      13    Debuff RES PEN +1%     1              1                3
# 49  50      13    Debuff RES PEN +2%     1              2                3
# 50  51      13    Debuff RES PEN +3%     1              3                3
# 51  52      13    Debuff RES PEN +5%     1              4                3
# 52  53      14    Healing Effect +1%     1              1                3
# 53  54      14    Healing Effect +3%     1              2                3
# 54  55      14    Healing Effect +5%     1              3                3
# 55  56      14   Healing Effect +10%     1              4                3
# 56  57      15  Basic Attributes +1%     1              1                3
# 57  58      15  Basic Attributes +2%     1              2                3
# 58  59      15  Basic Attributes +3%     1              3                3
# ...

# %% [markdown]
# attribute_label
# - attr 0 = level 2 skill
# - attr 1 = attack
# - attr 2 = defense
# - attr 3 = support

# %%
ware_bless
# Out:
#     type                            name  \
# 0      1         Divine Blessing: Legacy
# 1      2          Divine Blessing: Glory
# 2      3       Divine Blessing: Conquest
# 3      4      Divine Blessing: Authority
# 4      5        Divine Blessing: Clarity
# 5      6         Divine Blessing: Shield
# 6      7          Divine Blessing: Grace
# 7      8        Divine Blessing: Artisan
# 8      9        Supreme Blessing: Legacy
# 9     10        Supreme Blessing: Shield
# 10    11         Supreme Blessing: Grace
# 11    12      Supreme Blessing: Conquest
# 12    13       Supreme Blessing: Clarity
# 13    14     Supreme Blessing: Abundance
# 14    15   Impressive Blessing: Conquest
# 15    16     Impressive Blessing: Legacy
# 16    17  Impressive Blessing: Abundance
# 17    18    Impressive Blessing: Clarity
# 18    19      Impressive Blessing: Grace
# 19    20     Impressive Blessing: Shield
#
#                                                  desc      icon  \
# ...

# %%
ware_bless_gift
# Out:
#    gift_id             gift_name  charge_cfg_id old_price  limit_buy_count  \
# 0        1  Blessing Land Pack 1         146002    $49.99                1
# 1        2  Blessing Land Pack 2         146003    $99.99                1
# 2        3  Blessing Land Pack 3         146004   $149.99                5
# 3        4  Blessing Land Pack 4         146005   $299.99                9
#
#                           reward
# 0    5:3000245:10|1:2:500|10:180
# 1   5:3000245:20|1:2:1000|10:600
# 2  5:3000245:30|1:2:3000|10:3000
# 3  5:3000245:60|1:2:6000|10:6000

# %%
ware_bless_pool
# Out:
#    qulaity_level             name  weight  count_cannot_get  count_max_get
# 0              1    Blue Blessing     670                 0              0
# 1              2  Purple Blessing     300                 0              0
# 2              3    Gold Blessing      30                20             30

# %%
ware_common
# Out:
#    BLESS_CONSUME_GOODS_ID  BLESS_REACH_COUNT_CAN_CHOOSE  \
# 0                 3000245                           120
#
#    BLESS_MERGE_FOR_PURPLE  BLESS_MERGE_FOR_GOLD  MAX_WISH_BLESS_COUNT  \
# 0                      15                    15                     4
#
#    GAME_HAVE_HP  GAME_WEEK_CAN_PLAY_COUNT  SAME_ATTR_LEVEL_ADD_WEIGHT  \
# 0            10                         7                           5
#
#    SAME_ADDITIONAL_COLUMN_CAN_PUSH_MAX_COUNT RECYCLE_WARE_REWARD  \
# 0                                          3         5:3000245:1
#
#    GAME_PASS_CHARGE_ID  GAME_PASS_CHARGE_ADD_VIP_EXP  BLESS_SELECT_MAX  \
# 0               146001                           900                 3
#
#   WARE_GAME_SCENE_NAME  WARE_GAME_MOVE_MAP_TIME  \
# 0           YuanGuYiJi                        2
#
#    WARE_GAME_SELECT_HERO_DIALOG_HEIGHT1  WARE_GAME_SELECT_HERO_DIALOG_HEIGHT2
# 0                                   750                                   550

# %%
ware_game_achievement
# Out:
#     cfg_id  condition_type  need_reach_num       reward
# 0     1001               1              10  5:3000245:3
# 1     1002               1              20  5:3000245:3
# 2     2001               2               7  5:3000245:3
# 3     2002               2              14  5:3000245:3
# 4     2003               2              28  5:3000245:3
# 5     3001               3              30  5:3000245:1
# 6     3002               3              60  5:3000245:2
# 7     3003               3              90  5:3000245:3
# 8     3004               3             120  5:3000245:4
# 9     3005               3             150  5:3000245:5
# 10    4001               4              20  5:3000245:1
# 11    4002               4              40  5:3000245:2
# 12    4003               4              60  5:3000245:3
# 13    4004               4              80  5:3000245:4
# 14    4005               4             100  5:3000245:5
# 15    5001               5              10  5:3000245:5
# ...

# %%
ware_game_dungeon['drop_weight_by_quality_level'].unique()
# Out:
# array(['550|420|30|0', '530|410|60|0', '510|380|90|20', '490|350|125|35',
#        '490|350|125|36', '490|350|125|37', '490|350|125|38',
#        '490|350|125|39', '490|350|125|40', '490|350|125|41',
#        '490|350|125|42', '490|350|125|43', '490|350|125|44',
#        '470|330|150|50'], dtype=object)

# %%
ware_game_dungeon
# Out:
#     step  layer    name  type  npc_team_id drop_weight_by_quality_level  \
# 0      1      1     怪物1     1        10001                 550|420|30|0
# 1      2      1     怪物2     1        10002                 550|420|30|0
# 2      3      1     人物1     4            0                 550|420|30|0
# 3      4      1     怪物3     1        10003                 550|420|30|0
# 4      5      1     事件1     2            0                 550|420|30|0
# 5      6      1     怪物4     1        10004                 550|420|30|0
# 6      7      1     人物2     4            0                 550|420|30|0
# 7      8      1     怪物5     1        10005                 550|420|30|0
# 8      9      1     事件2     2            0                 550|420|30|0
# 9     10      1  Reward     3            0                 550|420|30|0
# 10    11      2     怪物1     1        20001                 530|410|60|0
# 11    12      2     怪物2     1        20002                 530|410|60|0
# ...

# %%
ware_game_event
# Out:
#    type                    name  weight
# 0     1                随机当前词条属性      30
# 1     2               复制一个低品质词条      30
# 2     3  提升一个词条的品质，已达到最高品质的不可提升       2
# 3     4       两个同品质词条，合成一个高品质词条      10
# 4     5               交换两个词条的品质      26

# %%
ware_game_hero
# Out:
#      cfg_id  hero_cid  quality_level  level  awake  if_advance  god_awake  \
# 0         1      2037              1    100      5           0          0
# 1         2      2037              2    200      5           1          5
# 2         3      2037              3    300      5           1          5
# 3         4      2037              4    400      5           1          5
# 4         5      2039              1    100      5           0          0
# ..      ...       ...            ...    ...    ...         ...        ...
# 115     116      2086              4    400      5           1          5
# 116     117      2087              1    100      5           1          1
# 117     118      2087              2    200      5           1          5
# 118     119      2087              3    300      5           1          5
# 119     120      2087              4    400      5           1          5
#
#      if_super  super_awake                       use_super_active_skills  ...  \
# ...

# %%
ware_game_hero.nunique()
# Out:
# cfg_id                     120
# hero_cid                    30
# quality_level                4
# level                        4
# awake                        1
# if_advance                   2
# god_awake                    3
# if_super                     2
# super_awake                  2
# use_super_active_skills      7
# if_mr                        2
# mr_awake                     2
# fight_value                  4
# max_hp                       4
# max_mp                       4
# min_attack                   4
# max_attack                   4
# defend                       4
# defend_ignore_level          4
# physc_def                    4
# magic_def                    4
# hit                          4
# dehit                        4
# crit                         4
# decrit                       4
# damage_add                   4
# damage_minus                 4
# crit_damage_add              4
# drain_hp                     4
# defend_ignore                4
# ...

# %%
ware_game_npc
# Out:
#      npc_id  hero_cid  quality_level  level  awake  if_advance  god_awake  \
# 0     10101      1001              1    100     32           0          0
# 1     10201      1001              2    200     38           0          0
# 2     10301      1001              3    300     38           1          5
# 3     10401      1001              4    400     38           1          5
# 4     10102      2037              1    100      5           0          0
# ..      ...       ...            ...    ...    ...         ...        ...
# 119   10430      2086              4    400      5           1          5
# 120   10131      2087              1    100      5           1          2
# 121   10231      2087              2    200      5           1          5
# 122   10331      2087              3    300      5           1          5
# 123   10431      2087              4    400      5           1          5
#
#      if_super  super_awake  if_mr  ...  damage_minus  crit_damage_add  \
# ...

# %%
ware_game_npc.rename(columns={'hero_cid': 'cid'}, inplace=True)

# %%
npc = ware_game_npc.merge(angels, on='cid', how='left')

# %%
npc[npc['npc_id'] == 10104].get('name').values[0]
# Out:
# 'Cupid'

# %%
angels
# Out:
#      cid  from_ur  is_sp  review_show  role  job  main  quality  \
# 0   1001        0      0            1     1    1     1        3
# 1   1002        0      0            1     1    1     1        3
# 2   1003        0      0            1     1    1     1        3
# 3   2001        0      0            0     2    1     1        5
# 4   2002        0      0            0     2    3     3        5
# ..   ...      ...    ...          ...   ...  ...   ...      ...
# 80  2083        0      0            0     2    1     1        6
# 81  2084        1      0            0     2    1     1        6
# 82  2085        0      0            0     2    3     3        6
# 83  2086        1      0            0     2    3     3        6
# 84  2087        1      0            0     2    2     2        6
#
#     quality_level  potential  ...  int_initial  sta_initial  \
# 0               1       3750  ...           50           50
# 1               1       3750  ...           50           50
# ...

# %%
ware_game_npc_team
# Out:
#     team_id  npc_level             npc_name  \
# 0     10001        200  Mirror of Illusions
# 1     10002        210  Mirror of Illusions
# 2     10003        220  Mirror of Illusions
# 3     10004        230  Mirror of Illusions
# 4     10005        240  Mirror of Illusions
# 5     20001        250  Mirror of Illusions
# 6     20002        260  Mirror of Illusions
# 7     20003        270  Mirror of Illusions
# 8     20004        280  Mirror of Illusions
# 9     20005        290  Mirror of Illusions
# 10    30001        300  Mirror of Illusions
# 11    30002        310  Mirror of Illusions
# 12    30003        320  Mirror of Illusions
# 13    30004        330  Mirror of Illusions
# 14    30005        340  Mirror of Illusions
# 15    40001        350  Mirror of Illusions
# 16    40002        360  Mirror of Illusions
# 17    40003        370  Mirror of Illusions
# 18    40004        380  Mirror of Illusions
# 19    40005        390  Mirror of Illusions
# ...

# %%
def get_name(npc_id):
    print(npc_id)
    angel = npc[npc['npc_id'] == int(npc_id)].get('name').values[0]
    return angel

# %%
ware_game_npc_team[['p1', 'p2', 'p3', 'p4', 'p5', 'p6']] = ware_game_npc_team['team'].str.split('|', expand=True)

# %%
ware_game_npc_team
# Out:
#     team_id  npc_level             npc_name  \
# 0     10001        200  Mirror of Illusions
# 1     10002        210  Mirror of Illusions
# 2     10003        220  Mirror of Illusions
# 3     10004        230  Mirror of Illusions
# 4     10005        240  Mirror of Illusions
# 5     20001        250  Mirror of Illusions
# 6     20002        260  Mirror of Illusions
# 7     20003        270  Mirror of Illusions
# 8     20004        280  Mirror of Illusions
# 9     20005        290  Mirror of Illusions
# 10    30001        300  Mirror of Illusions
# 11    30002        310  Mirror of Illusions
# 12    30003        320  Mirror of Illusions
# 13    30004        330  Mirror of Illusions
# 14    30005        340  Mirror of Illusions
# 15    40001        350  Mirror of Illusions
# 16    40002        360  Mirror of Illusions
# 17    40003        370  Mirror of Illusions
# 18    40004        380  Mirror of Illusions
# 19    40005        390  Mirror of Illusions
# ...

# %%
ware_game_npc_team['p1'] = ware_game_npc_team['p1'].apply(get_name)
ware_game_npc_team['p2'] = ware_game_npc_team['p2'].apply(get_name)
ware_game_npc_team['p3'] = ware_game_npc_team['p3'].apply(get_name)
ware_game_npc_team['p4'] = ware_game_npc_team['p4'].apply(get_name)
ware_game_npc_team['p5'] = ware_game_npc_team['p5'].apply(get_name)
ware_game_npc_team['p6'] = ware_game_npc_team['p6'].apply(get_name)
# Out:
# 10104
# 10122
# 10118
# 10107
# 10110
# 10203
# 10201
# 10228
# 10204
# 10206
# 10217
# 10223
# 10225
# 10204
# 10221
# 10203
# 10207
# 10210
# 10115
# 10224
# 10204
# 10224
# 10129
# 10218
# 10215
# 10110
# 10103
# 10109
# 10111
# 10116
# 10219
# 10224
# 10203
# 10206
# 10131
# 10221
# 10205
# 10220
# 10226
# 10219
# 10305
# 10303
# 10318
# 10314
# 10308
# 10129
# 10206
# 10209
# 10221
# 10214
# 10114
# 10121
# 10105
# 10126
# 10104
# 10120
# 10105
# 10101
# 10113
# 10121
# 10212
# 10206
# 10214
# 10216
# 10210
# 10229
# 10301
# 10326
# 10307
# 10326
# 10318
# 10231
# 10322
# 10313
# 10305
# 10124
# 10106
# 10102
# 10106
# 10125
# 10118
# 10128
# 10115
# 10101
# 10117
# 10216
# 10211
# 10131
# 10214
# 10214
# 10220
# 10202
# 10130
# 10204
# 10217
# 10322
# 10325
# 10313
# 10322
# 10326
# 10127
# 10115
# 10120
# 10122
# 10105
# 10113
# 10108
# 10120
# 10103
# 10112
# 10102
# 10104
# 10112
# 10109
# 10102
# 10110
# 10103
# 10111
# 10227
# 10118
# 10413
# 10330
# 10424
# 10417
# 10329
# ...

# %%
ware_game_npc_team
# Out:
#     team_id  npc_level             npc_name  \
# 0     10001        200  Mirror of Illusions
# 1     10002        210  Mirror of Illusions
# 2     10003        220  Mirror of Illusions
# 3     10004        230  Mirror of Illusions
# 4     10005        240  Mirror of Illusions
# 5     20001        250  Mirror of Illusions
# 6     20002        260  Mirror of Illusions
# 7     20003        270  Mirror of Illusions
# 8     20004        280  Mirror of Illusions
# 9     20005        290  Mirror of Illusions
# 10    30001        300  Mirror of Illusions
# 11    30002        310  Mirror of Illusions
# 12    30003        320  Mirror of Illusions
# 13    30004        330  Mirror of Illusions
# 14    30005        340  Mirror of Illusions
# 15    40001        350  Mirror of Illusions
# 16    40002        360  Mirror of Illusions
# 17    40003        370  Mirror of Illusions
# 18    40004        380  Mirror of Illusions
# 19    40005        390  Mirror of Illusions
# ...

# %%
enemies = ware_game_npc_team.drop(columns=['team', 'npc_name', 'test'])

# %%
enemies
# Out:
#     team_id  npc_level            p1            p2            p3  \
# 0     10001        200         Cupid  Frost Dragon    Sim Cheong
# 1     10002        210          Zeus          Hera         Venus
# 2     10003        220        Athena      Enmusubi        Icarus
# 3     10004        230      Heimdall  Ember Dragon         Horus
# 4     10005        240  Frost Dragon       Chang'e         Cupid
# 5     20001        250          Hera   Capricornus        Pisces
# 6     20002        260        Player          Thor        Icarus
# 7     20003        270          Ares          Hera        Player
# 8     20004        280         Cupid         Chaos        Freyja
# 9     20005        290         Chaos    Prometheus         Venus
# 10    30001        300         Asura         Venus  Storm Dragon
# 11    30002        310          Loki        Icarus         Chaos
# 12    30003        320        Apollo        Pisces    Sim Cheong
# ...

# %%
for i in os.listdir(img_ware_path):
    if len(i) < 9:
        img = img_ware_path + i
        display(Image(filename=img))
